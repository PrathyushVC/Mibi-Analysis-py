# %% [markdown]
# This notebook is designed to analyze MIBI data by performing data preprocessing, splitting the dataset into training, validation, and test sets, and preparing it for model training.
#
# The first step involves importing necessary libraries and modules, including polars for data manipulation and sklearn for dataset splitting.
#
# The dataset is loaded from a CSV file, and relevant columns are selected for further analysis.
#
# A GroupShuffleSplit is used to ensure that the data is split while maintaining the grouping of patients, which is crucial for avoiding data leakage.
#
# The training, validation, and test sets are printed to provide an overview of the data distribution.

# %%
import polars as pl
from sklearn.model_selection import train_test_split,GroupShuffleSplit
from torchvision import transforms
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#project imports 
import sys
notebook_path=os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_path,'NN_Framework')))
from NN_Framework import mibi_dataset

# %%
full_cell_sheet=pl.read_csv(r"D:\MIBI-TOFF\Data_For_Amos\cleaned_expression_with_both_classification_prob_spatial_30_08_24.csv")
print(full_cell_sheet.columns)
cell_frame = full_cell_sheet[['label', 'fov','pred','Group','patient number']]
unique_fovs = cell_frame.unique(subset='fov')
print(unique_fovs.head(5))
# Out:
# ['Unnamed: 0', 'cell_size', '128Te', '129Xe', '12C', '130Xe', '131Xe', '132Xe', '137Ba', '138Ba', '139La', '140Ce', '181Ta', '182Empty', '197Au', '23Na', '24Mg', '25Mg', '27Al', '28Si', '31P', '32Si', '39K', '40Ca', '41K', '56Fe', '64Zn', '66Zn', 'Alexa Fluor 488', 'Bax', 'CCR7', 'CD11c', 'CD14', 'CD163', 'CD20', 'CD206', 'CD21', 'CD3', 'CD31', 'CD4', 'CD45', 'CD45RA', 'CD45RO', 'CD56', 'CD68', 'CD69', 'CD8', 'COL1A1', 'DC-SIGN', 'Foxp3', 'Granzyme B', 'HLA-DR-DP-DQ', 'HLA-class-1-A-B-C', 'IDO-1', 'Ki67', 'LAG-3', 'MECA-79', 'MelanA', 'PD-1', 'S100A9-Calprotectin', 'SMA', 'SOX10', 'TCF1TCF7', 'TIM-3', 'Tox-Tox2', 'anti-Biotin', 'dsDNA', 'label', 'area', 'eccentricity', 'major_axis_length', 'minor_axis_length', 'perimeter', 'convex_area', 'equivalent_diameter', 'centroid-0', 'centroid-1', 'major_minor_axis_ratio', 'perim_square_over_area', 'major_axis_equiv_diam_ratio', 'convex_hull_resid', 'centroid_dif', 'num_concavities', 'fov', 'pred', 'pred_prob', 'class', 'score', 'spatial', 'Group', 'patient number']
# shape: (5, 5)
# ┌───────┬────────┬────────────────────────────┬───────┬────────────────┐
# │ label ┆ fov    ┆ pred                       ┆ Group ┆ patient number │
# │ ---   ┆ ---    ┆ ---                        ┆ ---   ┆ ---            │
# │ f64   ┆ str    ┆ str                        ┆ str   ┆ i64            │
# ╞═══════╪════════╪════════════════════════════╪═══════╪════════════════╡
# │ 1.0   ┆ FOV408 ┆ Mono_CD14_DR               ┆ G4    ┆ 117            │
# │ 1.0   ┆ FOV20  ┆ Memory_CD4_T_Cells         ┆ G1    ┆ 5              │
# │ 1.0   ┆ FOV234 ┆ Follicular_Germinal_B_Cell ┆ G2    ┆ 22             │
# │ 1.0   ┆ FOV366 ┆ Memory_CD4_T_Cells         ┆ G2    ┆ 44             │
# │ 1.0   ┆ FOV268 ┆ DC sign Mac                ┆ G2    ┆ 57             │
# └───────┴────────┴────────────────────────────┴───────┴────────────────┘

# %%
train_val_splitter = GroupShuffleSplit(n_splits=1, test_size=0.40, random_state=1995)
train_idx, temp_idx = next(train_val_splitter.split(unique_fovs, groups=unique_fovs['patient number']))
train_data = unique_fovs[train_idx]

# Split the remaining data into validation and testing sets
val_test_splitter = GroupShuffleSplit(n_splits=1, test_size=0.25, random_state=1995)
val_idx, test_idx = next(val_test_splitter.split(unique_fovs[temp_idx], groups=unique_fovs[temp_idx]['patient number']))
val_data = unique_fovs[temp_idx][val_idx]
test_data = unique_fovs[temp_idx][test_idx]

print("Training Set:")
print(f"Length of training data: {len(train_data)}")
print(train_data.head(5),)
print("\nValidation Set:")
print(f"Length of training data: {len(val_data)}")
print(val_data.head(5))
print("\nTesting Set:")
print(f"Length of training data: {len(test_data)}")
print(test_data.head(5))


import pickle
from datetime import datetime

# Add date_time to the data
data_to_save = {
    'train_data': train_data.to_dict(),
    'val_data': val_data.to_dict(),
    'test_data': test_data.to_dict(),
    'date_time': datetime.now().isoformat()  # Adding current date and time
}

# Define the filename with the current date and time
filename = f'data_split_{datetime.now().strftime("%Y%m%d_%H%M%S")}.pkl'

with open(filename, 'wb') as pickle_file:
    pickle.dump(data_to_save, pickle_file)

print(f"Data saved to '{filename}' with current date and time.")
# Out:
# Training Set:
# Length of training data: 100
# shape: (5, 5)
# ┌───────┬────────┬────────────────────────────┬───────┬────────────────┐
# │ label ┆ fov    ┆ pred                       ┆ Group ┆ patient number │
# │ ---   ┆ ---    ┆ ---                        ┆ ---   ┆ ---            │
# │ f64   ┆ str    ┆ str                        ┆ str   ┆ i64            │
# ╞═══════╪════════╪════════════════════════════╪═══════╪════════════════╡
# │ 1.0   ┆ FOV234 ┆ Follicular_Germinal_B_Cell ┆ G2    ┆ 22             │
# │ 1.0   ┆ FOV366 ┆ Memory_CD4_T_Cells         ┆ G2    ┆ 44             │
# │ 1.0   ┆ FOV268 ┆ DC sign Mac                ┆ G2    ┆ 57             │
# │ 1.0   ┆ FOV110 ┆ Unidentified               ┆ G4    ┆ 119            │
# │ 1.0   ┆ FOV150 ┆ B cell                     ┆ G2    ┆ 47             │
# └───────┴────────┴────────────────────────────┴───────┴────────────────┘
#
# Validation Set:
# Length of training data: 58
# shape: (5, 5)
# ┌───────┬────────┬────────────────────┬───────┬────────────────┐
# │ label ┆ fov    ┆ pred               ┆ Group ┆ patient number │
# │ ---   ┆ ---    ┆ ---                ┆ ---   ┆ ---            │
# │ f64   ┆ str    ┆ str                ┆ str   ┆ i64            │
# ╞═══════╪════════╪════════════════════╪═══════╪════════════════╡
# │ 1.0   ┆ FOV408 ┆ Mono_CD14_DR       ┆ G4    ┆ 117            │
# │ 1.0   ┆ FOV20  ┆ Memory_CD4_T_Cells ┆ G1    ┆ 5              │
# │ 1.0   ┆ FOV332 ┆ Unidentified       ┆ G4    ┆ 115            │
# │ 1.0   ┆ FOV220 ┆ Unidentified       ┆ G1    ┆ 16             │
# │ 1.0   ┆ FOV356 ┆ CD4 APC            ┆ G4    ┆ 118            │
# └───────┴────────┴────────────────────┴───────┴────────────────┘
#
# Testing Set:
# Length of training data: 19
# shape: (5, 5)
# ┌───────┬────────┬──────────────┬───────┬────────────────┐
# │ label ┆ fov    ┆ pred         ┆ Group ┆ patient number │
# │ ---   ┆ ---    ┆ ---          ┆ ---   ┆ ---            │
# │ f64   ┆ str    ┆ str          ┆ str   ┆ i64            │
# ╞═══════╪════════╪══════════════╪═══════╪════════════════╡
# │ 1.0   ┆ FOV168 ┆ B cell       ┆ G3    ┆ 89             │
# │ 1.0   ┆ FOV158 ┆ Unidentified ┆ G3    ┆ 86             │
# │ 1.0   ┆ FOV262 ┆ B cell       ┆ G3    ┆ 91             │
# │ 1.0   ┆ FOV156 ┆ Neutrophil   ┆ G3    ┆ 86             │
# │ 1.0   ┆ FOV46  ┆ CD8 T cell   ┆ G2    ┆ 37             │
# └───────┴────────┴──────────────┴───────┴────────────────┘
# Data saved to 'data_split_20241114_224805.pkl' with current date and time.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pickle

# Load the data from the pickle file
with open(r'D:\MIBI-TOFF\Mibi-Analysis-py\data_split_20241027_202034.pkl', 'rb') as pickle_file:
    data_loaded = pickle.load(pickle_file)

train_data = pl.DataFrame(data_loaded['train_data'])
val_data = pl.DataFrame(data_loaded['val_data'])
test_data = pl.DataFrame(data_loaded['test_data'])

# %%
root_dir=data_path=r'D:\MIBI-TOFF\Data_For_Amos'
df=unique_fovs
prefix='FOV'
fov_col='fov'
label_col='Group'
image_paths=[]

# The loop moves through the predefined file structure of the MIBI dataset being used to identify relevent image samples while filtering out files that we do not want
#Theoretically provides 39 expressions but some patients have varying amounts
for fov_dir in os.listdir(root_dir):
            if fov_dir.startswith(prefix):#replace with Pathlib matching later
                fov_path = os.path.join(root_dir, fov_dir)
                
                if os.path.isdir(fov_path):
                    #print(fov_dir)
                    group = df.filter(pl.col(fov_col) == fov_dir)  #why oh why did I decide to decide to use polars instead of pandas for this test?
                    if group.height>0:
                        group_data = group[label_col].to_list()[0]  
                        #print(group_data,binarized_data)
                        tif_path = os.path.join(fov_path, 'TIFs')
                        if os.path.exists(tif_path):
                            # Load all .tiff files ignoring those with "segmentation in the name"
                            sublist=[]
                            for image_file in os.listdir(tif_path):
                                if (image_file.endswith('.tif') or image_file.endswith('.tiff')) and ('segmentation' not in image_file) and not (image_file[0].isdigit()):
                                    sublist.append(os.path.join(tif_path, image_file))
                            

                            sublist.sort()#Should normalize the data assuming the data format is maintained true for this dataset 
                            #should create a perminant mapping
                            image_paths.append(sublist)
                        num_sublists = len(sublist)

# %%
#Find the expressions that are not in every file should be equal to the number of fovs 177 in this sample
expressions={}


for fov in image_paths:
    for path in fov:
        filename = os.path.basename(path)
        if filename not in expressions:
            expressions[filename]=1
        else:
            expressions[filename]+=1
print(expressions)
# Out:
# {'Alexa Fluor 488.tif': 177, 'Bax.tif': 177, 'CCR7.tif': 177, 'CD11c.tif': 177, 'CD14.tif': 177, 'CD163.tif': 177, 'CD20.tif': 177, 'CD206.tif': 177, 'CD21.tif': 177, 'CD3.tif': 177, 'CD31.tif': 177, 'CD4.tif': 177, 'CD45.tif': 177, 'CD45RA.tif': 177, 'CD45RO.tif': 177, 'CD56.tif': 177, 'CD68.tif': 177, 'CD69.tif': 177, 'CD8.tif': 177, 'COL1A1.tif': 177, 'DC-SIGN.tif': 177, 'Foxp3.tif': 177, 'Granzyme B.tif': 177, 'HLA-DR-DP-DQ.tif': 177, 'HLA-class-1-A-B-C.tif': 177, 'IDO-1.tif': 177, 'Ki67.tif': 177, 'LAG-3.tif': 177, 'MECA-79.tif': 177, 'MelanA.tif': 177, 'PD-1.tif': 177, 'S100A9-Calprotectin.tif': 177, 'SMA.tif': 177, 'SOX10.tif': 177, 'TCF1TCF7.tif': 177, 'TIM-3.tif': 177, 'Tox-Tox2.tif': 177, 'anti-Biotin.tif': 177, 'dsDNA.tif': 177, 'dsDNA-enhanced.tif': 9, 'dsDNA_cont.tif': 6, 'mask_fov_164.tif': 1, 'CD4_smooth.tif': 3, 'Foxp3_smooth.tif': 1, 'CD14_smooth.tif': 1, 'CD31_smooth.tif': 1, 'CD8_smooth.tif': 2, 'MelanA_enhanced.tif': 1, 'MelanA_smooth.tif': 1, 'S100A9-Calprotectin_smooth.tif': 1, 'dsDNA_smooth.tif': 3, 'dsDNA_enhanced.tif': 2, 'CD20_Smooth.tif': 1, 'CD20_gaussian.tif': 1, 'CD3_gaussian.tif': 1, 'CD3_smooth.tif': 1, 'CD4_gaussian.tif': 1, 'SOX10_gaussian.tif': 1, 'SOX10_smooth.tif': 1, 'CD163_gaussian_2.tif': 1, 'CD163_smooth.tif': 1, 'CD8_gaussian.tif': 1, 'Stack.tif': 1}

# %%
threshold=117
consistent_expressions=[key for key, value in expressions.items() if value > threshold]
#I have no idea why > is needed to make this work
print(len(consistent_expressions))
print(consistent_expressions)
# Out:
# 39
# ['Alexa Fluor 488.tif', 'Bax.tif', 'CCR7.tif', 'CD11c.tif', 'CD14.tif', 'CD163.tif', 'CD20.tif', 'CD206.tif', 'CD21.tif', 'CD3.tif', 'CD31.tif', 'CD4.tif', 'CD45.tif', 'CD45RA.tif', 'CD45RO.tif', 'CD56.tif', 'CD68.tif', 'CD69.tif', 'CD8.tif', 'COL1A1.tif', 'DC-SIGN.tif', 'Foxp3.tif', 'Granzyme B.tif', 'HLA-DR-DP-DQ.tif', 'HLA-class-1-A-B-C.tif', 'IDO-1.tif', 'Ki67.tif', 'LAG-3.tif', 'MECA-79.tif', 'MelanA.tif', 'PD-1.tif', 'S100A9-Calprotectin.tif', 'SMA.tif', 'SOX10.tif', 'TCF1TCF7.tif', 'TIM-3.tif', 'Tox-Tox2.tif', 'anti-Biotin.tif', 'dsDNA.tif']

# %%
#Reduced lists of expressions
expression_types = ['MelanA.tif', 'Ki67.tif', 'SOX10.tif', 'COL1A1.tif', 'SMA.tif', 'CD206.tif', 'CD8.tif', 'CD4.tif', 'CD45.tif', 'CD3.tif', 'CD20.tif', 'CD11c.tif']

# %%
expressions_test={}
for fov in image_paths:
    print(fov[0],len(fov))
    for path in fov:
        
        filename = os.path.basename(path)
        if filename not in expressions_test:
            expressions_test[filename]=1
        else:
            expressions_test[filename]+=1
len(image_paths)
# Out:
# D:\MIBI-TOFF\Data_For_Amos\FOV10\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV100\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV102\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV104\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV106\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV108\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV110\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV112\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV114\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV116\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV118\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV12\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV120\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV122\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV124\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV126\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV128\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV130\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV132\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV134\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV136\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV138\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV14\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV140\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV142\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV144\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV146\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV148\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV150\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV152\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV154\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV156\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV158\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV16\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV160\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV162\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV164\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV166\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV168\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV170\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV172\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV174\TIFs\Alexa Fluor 488.tif 41
# D:\MIBI-TOFF\Data_For_Amos\FOV176\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV178\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV18\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV180\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV182\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV184\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV190\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV192\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV194\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV196\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV198\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV2\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV20\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV204\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV206\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV212\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV218\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV22\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV220\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV222\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV224\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV226\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV228\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV230\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV232\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV234\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV236\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV238\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV24\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV240\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV246\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV248\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV250\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV252\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV258\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV26\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV260\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV262\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV268\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV270\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV272\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV274\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV278\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV28\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV280\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV282\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV284\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV286\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV288\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV294\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV296\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV298\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV30\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV300\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV302\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV304\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV306\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV308\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV32\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV322\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV324\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV326\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV332\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV334\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV336\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV338\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV34\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV342\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV344\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV350\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV352\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV354\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV356\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV358\TIFs\Alexa Fluor 488.tif 47
# D:\MIBI-TOFF\Data_For_Amos\FOV36\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV362\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV364\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV366\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV368\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV370\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV372\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV374\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV38\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV380\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV382\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV384\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV390\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV392\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV394\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV4\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV40\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV400\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV402\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV404\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV406\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV408\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV410\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV412\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV418\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV42\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV420\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV422\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV424\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV426\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV428\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV44\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV46\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV48\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV50\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV52\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV54\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV56\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV58\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV6\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV60\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV62\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV64\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV66\TIFs\Alexa Fluor 488.tif 40
# D:\MIBI-TOFF\Data_For_Amos\FOV68\TIFs\Alexa Fluor 488.tif 48
# D:\MIBI-TOFF\Data_For_Amos\FOV70\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV72\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV74\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV76\TIFs\Alexa Fluor 488.tif 45
# D:\MIBI-TOFF\Data_For_Amos\FOV78\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV8\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV80\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV82\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV84\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV86\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV88\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV90\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV92\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV94\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV96\TIFs\Alexa Fluor 488.tif 39
# D:\MIBI-TOFF\Data_For_Amos\FOV98\TIFs\Alexa Fluor 488.tif 39
# 177

# %%
import os
from NN_Framework import mibi_data_prep
import importlib

# %%
ps=1024
output_path=r'D:\MIBI-TOFF\Scratch'

hdf5_path = os.path.join(output_path, 'training_1024h5') 

train_hdf5 = mibi_data_prep.fovs_to_hdf5(root_dir=data_path, df=train_data,patch_size_x=ps, patch_size_y=ps,hdf5_path=hdf5_path, prefix='FOV', fov_col='fov', label_col='Group', expressions=expression_types)

hdf5_path = os.path.join(output_path, 'validation_1024.h5') 

val_hdf5 = mibi_data_prep.fovs_to_hdf5(root_dir=data_path, df=val_data,patch_size_x=ps, patch_size_y=ps,hdf5_path=hdf5_path, prefix='FOV', fov_col='fov', label_col='Group', expressions=expression_types)

hdf5_path = os.path.join(output_path, 'testing_1024.h5') 
test_hdf5 = mibi_data_prep.fovs_to_hdf5(root_dir=data_path, df=test_data,patch_size_x=ps, patch_size_y=ps,hdf5_path=hdf5_path, prefix='FOV', fov_col='fov', label_col='Group', expressions=expression_types)
# Out:
# D:\MIBI-TOFF\Data_For_Amos\FOV120 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV122 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV14 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV156 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV158 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV16 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV160 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV162 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV164 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV166 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV168 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV170 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV18 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV182 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV186 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV188 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV192 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV194 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV20 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV206 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV212 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV214 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV216 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV236 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV238 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV242 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV30 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV310 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV312 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV314 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV316 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV318 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV32 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV320 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV326 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV332 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV334 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV340 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV372 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV374 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV386 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV388 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV396 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV398 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV46 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV48 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV54 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV56 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV58 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV60 is not in provided Dataframe
# 473
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# D:\MIBI-TOFF\Scratch\training_1024h5
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 4
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 8
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 9
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 10
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 11
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 12
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 13
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 17
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 21
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 25
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 29
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 33
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 37
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 41
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 45
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 49
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 53
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 57
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 61
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 65
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 69
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 73
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 77
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 81
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 85
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 89
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 93
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 97
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 101
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 105
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 106
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 107
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 111
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 115
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 116
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 120
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 124
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 128
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 132
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 136
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 140
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 144
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 148
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 152
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 156
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 160
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 164
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 168
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 172
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 176
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 180
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 184
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 188
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 192
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 196
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 200
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 204
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 208
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 212
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 216
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 220
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 224
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 228
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 232
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 236
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 240
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 244
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 248
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 252
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 256
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 260
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 264
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 265
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 266
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 270
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 274
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 278
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 282
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 286
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 290
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 291
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 292
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 296
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 297
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 301
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 305
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 309
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 313
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 317
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 321
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 325
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 326
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 327
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 331
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 335
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 339
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 343
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 344
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 345
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 346
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 347
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 348
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 349
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 353
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 357
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 358
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 359
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 360
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 364
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 365
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 366
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 370
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 371
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 375
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 376
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 380
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 381
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 382
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 383
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 387
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 391
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 395
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 399
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 403
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 407
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 411
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 415
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 419
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 423
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 424
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 428
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 432
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 436
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 440
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 441
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 445
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 449
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 453
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 457
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 461
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 465
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 469
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 473
# D:\MIBI-TOFF\Data_For_Amos\FOV10 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV100 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV102 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV104 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV106 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV108 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV110 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV112 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV114 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV116 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV118 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV12 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV124 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV126 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV128 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV130 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV132 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV134 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV136 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV138 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV14 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV140 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV142 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV144 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV146 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV148 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV150 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV152 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV154 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV156 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV158 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV16 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV160 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV168 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV170 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV172 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV174 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV176 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV178 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV180 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV182 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV184 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV186 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV188 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV190 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV192 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV194 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV196 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV198 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV2 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV204 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV206 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV212 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV214 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV216 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV218 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV22 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV220 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV222 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV224 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV226 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV228 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV230 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV232 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV234 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV24 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV240 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV242 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV246 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV248 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV250 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV252 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV258 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV26 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV260 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV262 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV268 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV270 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV272 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV274 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV278 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV28 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV280 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV282 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV284 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV286 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV288 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV294 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV296 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV298 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV300 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV302 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV304 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV306 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV308 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV310 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV312 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV314 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV316 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV318 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV320 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV322 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV324 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV326 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV332 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV334 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV336 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV338 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV34 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV340 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV342 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV344 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV350 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV352 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV354 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV356 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV358 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV36 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV362 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV364 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV366 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV368 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV370 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV372 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV374 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV38 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV380 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV382 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV384 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV386 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV388 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV390 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV392 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV394 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV396 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV398 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV4 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV40 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV400 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV402 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV404 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV406 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV408 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV410 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV412 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV418 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV42 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV420 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV422 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV424 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV426 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV428 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV44 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV50 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV52 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV6 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV62 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV64 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV66 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV68 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV70 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV72 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV74 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV76 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV78 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV8 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV80 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV82 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV84 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV86 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV88 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV90 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV92 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV94 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV96 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV98 is not in provided Dataframe
# 68
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# D:\MIBI-TOFF\Scratch\validation_1024.h5
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 4
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 8
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 12
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 16
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 20
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 24
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 28
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 32
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 36
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 40
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 44
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 48
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 52
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 56
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 60
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 64
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 68
# D:\MIBI-TOFF\Data_For_Amos\FOV10 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV100 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV102 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV104 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV106 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV108 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV110 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV112 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV114 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV116 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV118 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV12 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV120 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV122 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV124 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV126 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV128 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV130 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV132 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV134 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV136 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV138 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV140 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV142 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV144 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV146 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV148 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV150 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV152 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV154 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV162 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV164 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV166 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV172 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV174 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV176 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV178 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV18 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV180 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV184 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV186 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV188 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV190 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV196 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV198 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV2 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV20 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV204 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV214 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV216 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV218 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV22 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV220 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV222 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV224 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV226 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV228 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV230 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV232 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV234 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV236 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV238 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV24 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV240 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV242 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV246 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV248 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV250 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV252 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV258 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV26 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV260 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV262 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV268 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV270 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV272 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV274 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV278 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV28 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV280 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV282 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV284 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV286 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV288 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV294 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV296 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV298 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV30 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV300 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV302 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV304 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV306 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV308 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV310 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV312 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV314 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV316 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV318 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV32 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV320 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV322 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV324 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV336 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV338 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV34 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV340 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV342 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV344 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV350 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV352 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV354 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV356 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV358 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV36 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV362 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV364 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV366 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV368 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV370 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV38 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV380 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV382 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV384 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV386 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV388 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV390 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV392 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV394 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV396 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV398 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV4 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV40 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV400 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV402 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV404 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV406 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV408 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV410 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV412 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV418 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV42 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV420 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV422 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV424 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV426 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV428 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV44 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV46 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV48 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV50 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV52 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV54 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV56 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV58 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV6 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV60 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV62 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV64 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV66 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV68 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV70 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV72 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV74 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV76 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV78 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV8 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV80 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV82 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV84 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV86 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV88 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV90 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV92 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV94 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV96 is not in provided Dataframe
# D:\MIBI-TOFF\Data_For_Amos\FOV98 is not in provided Dataframe
# 62
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# D:\MIBI-TOFF\Scratch\testing_1024.h5
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 4
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 8
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 12
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 16
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 20
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 24
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 28
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 32
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 36
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 40
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 44
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 48
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 52
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 56
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 60
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 61
# Keys in the HDF5 file:
# ['labels', 'locations', 'patches']
# 62
